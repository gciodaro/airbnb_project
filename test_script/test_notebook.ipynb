# %%
import numpy as np

# %% [markdown]
# # Test import function from module
# + simplest case

# %%
from test_script import sum_integers
test_on_sum = sum_integers(2,3)
test_on_sum
# Out:
# 5

# %%
print(test_on_sum)
# Out:
# 5

# %% [markdown]
# # Example of plot
# + using matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# make the data
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 24)
y = 4 + np.random.normal(0, 2, len(x))

# %%
# plot
fig, ax = plt.subplots()
ax.scatter(x, y)
plt.show()

# %%
# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)
# plot
fig, ax = plt.subplots()
ax.plot(x, y, linewidth=2.0)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))
plt.show()
